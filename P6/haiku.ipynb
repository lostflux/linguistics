# %% [markdown]
# # Template for Exercise 6.2: Haikus in English, created using a CFG
# Dartmouth College, CS 72/LING 48, Winter 2024<br>
# Kenneth Lai (Kenneth.Han.Lai@dartmouth.edu)

# %% [markdown]
# #### Assignment Submitted by: Amittai Siavava

# %%
from nltk import CFG
from nltk.parse.generate import generate
import pyphen

# %%
dic = pyphen.Pyphen(lang='en')
def count_syllables(word):
  sylls = dic.inserted(word)
  return sylls.count("-") + 1

# %%
# NOTE: Adapted from examples at https://capitalizemytitle.com/

# # one-syllable words
# W1 = {
#     "strong", "big", "soft"#, "smart", "best", "thin", "clear", "sweet", "wild", "plain", "lean"   # adjectives
#   , "key", "faith", "breath"#, "peace", "cake", "bed", "rock", "home", "hate", "zone"              # nouns
#   , "go", "do", "be", "see"#, "die", "lie", "cry", "fly", "buy", "try"                              # verbs
# }

# # two-syllable words
# W2 = {
#     "happy", "pretty", "silly"#, "lovely", "crazy", "lucky", "funny", "angry", "ugly", "dirty"      # adjectives
#   , "sister", "brother", "mother"#, "father", "friend", "people"                                    # nouns
#   , "listen", "whisper", "answer"#, "travel", "wonder", "happen", "open", "enter", "gather"         # verbs 
# }

# # three-syllable words
# W3 = {
#     "beautiful", "dangerous", "mysterious"#, "delicious", "curious", "serious", "wonderful"          # adjectives
#   , "daughter", "teacher", "manager"#, "visitor", "stranger", "neighbor"                             # nouns
#   , "remember", "discover", "consider"#, "encounter", "wander", "listen", "whisper"        # verbs
# }

# # four-syllable words
# W4 = {
#     "important", "impossible", "incredible"#, "unbelievable", "unforgettable"                        # adjectives
#   , "ambassador", "celebration", "communication"#, "conversation", "entertainment"                   # nouns
#   , "understand", "appreciate", "communicate"#, "concentrate", "celebrate", "entertain"              # verbs
# }

# # five-syllable words
# W5 = {
#     "conversational", "inexcusable", "impressionable"#, "intolerable", "irreplaceable", "unacceptable", "supernatural", "apologetic"          # adjectives
#   , "abomination", "capitalism", "communication"#, "organization", "manipulator", "accumulation", "cabability", "characteristic"               # nouns
#   , "deteriorate", "decontaminate", "deactivate"#, "incapacitate", "underestimate", "overcompensate", "conceptualize", "overestimate"          # verbs
# }

# # six-syllable words
# W6 = {
#     "categorizable", "hallucinogenic", "differentiated"#, "identifiable", "ecclesiastical"                         # adjectives
#   , "capitalization", "divisibility", "disassociacion"#, "humidification", "idealization", "excommunication"       # nouns
#   , "intercommunicate", "editorialize", "overgeneralize"#, "telecommunicate"                                      # verbs
# }

# W7 = {
#     "unconventionality", "sentimentalization", "immeasurability"#, "irreversibility", "impermiability", "compartmentalization"  # nouns
#   , "microbiological", "inadmissibility", "neuropsychological" # adjectives"
# }

DET1 = {
  "a", "an", "the"
}

ADJ1 = {
  "old", "every"
}

PREP1 = {
  "of", "in", "on", "at", "by", "with", "to", "from", "for"
}

CONJ1 = {
  "and", "or", "but"
}

ADV1 = {
  "again",
}

NOUN1 = {
  "pond", "frog", "world", "dew", "struggle", "splash"
}

PNOUN1 = {
  "I", "you", "he", "she", "it", "we", "they"
}

VERB1 = {
  "jumps", "splash"
}

# W1 = {
#     "a"
#   , "an"
#   , "old"
#   , "pond"
#   , "frog"
#   , "jumps"
#   , "the"
#   , "pond"
#   , "splash"
#   , "again"
#   , "world"
#   , "dew"
#   , "of"
#   , "and"
#   , "every"
#   , "struggle"
# }

# 2-syllable nouns
NOUN2 = {
  "dewdrop", "silence", "within"
}

# 2-syllable verbs
VERB2 = {
  "listen", "whisper", "answer", "travel", "wonder", "happen", "open", "enter", "gather"
}

# W2 = {
#     "silent"
#   , "within"
#   , "dewdrop"
#   , "silence"
#   , "into"
# }

C1 = { w: count_syllables(w) for w in VERB2 }
C2 = { w: count_syllables(w) for w in NOUN2 }
print(f"{C1=}")
print(f"{C2=}")
# Out:
# C1={'travel': 1, 'answer': 2, 'open': 1, 'wonder': 2, 'gather': 2, 'listen': 1, 'enter': 1, 'happen': 2, 'whisper': 2}
# C2={'dewdrop': 2, 'silence': 2, 'within': 2}

# %%
# count syllables
C1 = { w: count_syllables(w) for w in W1 }
C2 = { w: count_syllables(w) for w in W2 }
print(f"{C1=}")
print(f"{C2=}")
# Out:
# C1={'frog': 1, 'an': 1, 'the': 1, 'pond': 1, 'a': 1, 'old': 1, 'into': 2, 'jumps': 1}
# C2={'silent': 2}

# %%
        # SOMETHING2 -> W1 W6 | W2 W5 | W3 W4 | W4 W3 | W5 W2 | W6 W1

raw_s = f"""
        
        S -> SOMETHING1 BREAK SOMETHING2 BREAK SOMETHING3
        
        SOMETHING1 -> W1 W4 | W2 W3 | W3 W2 | W4 W1
        SOMETHING2 -> W3 W2 W3 | W4 W1 W2
        SOMETHING3 -> W4 W1 | W3 W2 | W1 W4 | W2 W3
        
        BREAK -> "|"
        
        W1 -> { " | ".join([ f"'{word}'" for word in W1 ]) }
        W2 -> { " | ".join([ f"'{word}'" for word in W2 ]) }
        W3 -> { " | ".join([ f"'{word}'" for word in W3 ]) }
        W4 -> { " | ".join([ f"'{word}'" for word in W4 ]) }
        W5 -> { " | ".join([ f"'{word}'" for word in W5 ]) }
        
    """
    
print(f"{raw_s}\n\n")

cfgGrammarHaiku = CFG.fromstring(raw_s)
# Out:
# S -> SOMETHING1 BREAK SOMETHING2 BREAK SOMETHING3
#
# SOMETHING1 -> W1 W4 | W2 W3 | W3 W2 | W4 W1
# SOMETHING2 -> W3 W2 W3 | W4 W1 W2
# SOMETHING3 -> W4 W1 | W3 W2 | W1 W4 | W2 W3
#
# BREAK -> "|"
#
# W1 -> 'key' | 'go' | 'be' | 'see' | 'soft' | 'strong' | 'faith' | 'big' | 'breath' | 'do'
# W2 -> 'sister' | 'silly' | 'listen' | 'pretty' | 'whisper' | 'answer' | 'brother' | 'mother' | 'happy'
# W3 -> 'dangerous' | 'mysterious' | 'manager' | 'consider' | 'remember' | 'teacher' | 'beautiful' | 'daughter' | 'discover'
# W4 -> 'important' | 'ambassador' | 'incredible' | 'appreciate' | 'understand' | 'celebration' | 'communicate' | 'communication' | 'impossible'
# W5 -> 'capitalism' | 'deteriorate' | 'abomination' | 'inexcusable' | 'impressionable' | 'communication' | 'conversational' | 'deactivate' | 'decontaminate'

# %%
counter = 0
for sentence in generate(cfgGrammarHaiku):
    if counter % 1_000_000 == 0:
        print(f"{counter:10d}: {' '.join(sentence)}")
    
    if counter > 500_000_000:
        break
    
    counter += 1

print("\nSo far we have generated " + str(counter) + " sentences.")
# Out:
#          0: key important | dangerous sister dangerous | important key
#    1000000: key ambassador | communication be mother | happy mysterious
#    2000000: key appreciate | celebration strong brother | mother manager
#    3000000: key celebration | appreciate breath answer | brother consider
#    4000000: key communication | incredible go whisper | answer remember
#    5000000: go important | important soft pretty | whisper teacher
#    6000000: go incredible | daughter answer manager | pretty beautiful
#    7000000: go understand | teacher brother mysterious | listen daughter
#    8000000: go communicate | consider mother dangerous | silly discover
#    9000000: go impossible | mysterious mother discover | silly dangerous
#   10000000: be important | impossible do mother | sister mysterious
#   11000000: be incredible | communication be brother | do incredible
#   12000000: be understand | celebration strong answer | breath appreciate
#   13000000: be communicate | appreciate breath whisper | big understand
#   14000000: be impossible | incredible go pretty | faith celebration
#   15000000: see ambassador | important soft listen | strong communicate
#   16000000: see appreciate | daughter answer mysterious | soft communication
#   17000000: see celebration | teacher brother dangerous | see impossible
#   18000000: see communication | consider brother discover | see important
#   19000000: soft important | mysterious mother daughter | be ambassador
#   20000000: soft ambassador | impossible do brother | go incredible
#   21000000: soft appreciate | communication be answer | key appreciate
#   22000000: soft celebration | celebration strong whisper | discover whisper
#   23000000: soft communication | appreciate breath pretty | daughter answer
#   24000000: strong important | incredible go listen | beautiful brother
#   25000000: strong incredible | important soft silly | teacher mother
#   26000000: strong understand | daughter answer dangerous | remember happy
#   27000000: strong communicate | teacher answer discover | remember sister
#   28000000: strong impossible | consider brother daughter | consider silly
#   29000000: faith ambassador | mysterious mother beautiful | manager listen
#   30000000: faith incredible | impossible do answer | mysterious pretty
#   31000000: faith understand | communication be whisper | dangerous whisper
#   32000000: faith communicate | celebration strong pretty | impossible faith
#   33000000: faith impossible | appreciate breath listen | communication breath
#   34000000: big ambassador | incredible go silly | communication key
#   35000000: big appreciate | important soft sister | communicate be
#   36000000: big celebration | daughter whisper discover | celebration soft
#   37000000: big communication | teacher answer daughter | understand faith
#   38000000: breath important | consider brother beautiful | appreciate breath
#   39000000: breath incredible | mysterious mother teacher | appreciate key
#   40000000: breath appreciate | impossible do whisper | incredible be
#   41000000: breath celebration | communication be pretty | ambassador soft
#   42000000: breath communication | celebration strong listen | important faith
#   43000000: do important | appreciate breath sister | happy daughter
#   44000000: do incredible | incredible key happy | mother discover
#   45000000: do understand | important see mother | mother dangerous
#   46000000: do communicate | daughter whisper beautiful | brother mysterious
#   47000000: do impossible | teacher answer teacher | answer manager
#   48000000: sister mysterious | consider brother remember | whisper consider
#   49000000: sister consider | mysterious mother consider | pretty remember
#   50000000: sister remember | impossible do listen | listen teacher
#   51000000: sister beautiful | communication be silly | silly beautiful
#   52000000: sister discover | celebration strong sister | sister daughter
#   53000000: silly mysterious | appreciate big happy | do impossible
#   54000000: silly consider | incredible key mother | do important
#   55000000: silly teacher | important see brother | breath ambassador
#   56000000: silly daughter | daughter whisper teacher | big incredible
#   57000000: listen dangerous | teacher answer remember | faith appreciate
#   58000000: listen manager | consider brother consider | strong understand
#   59000000: listen remember | mysterious mother manager | soft celebration
#   60000000: listen teacher | impossible do silly | see communicate
#   61000000: listen daughter | communication be sister | be communication
#   62000000: pretty dangerous | celebration soft happy | go impossible
#   63000000: pretty manager | appreciate big mother | go important
#   64000000: pretty remember | incredible key brother | key ambassador
#   65000000: pretty beautiful | important see answer | discover listen
#   66000000: pretty discover | daughter whisper remember | daughter pretty
#   67000000: whisper mysterious | teacher answer consider | beautiful whisper
#   68000000: whisper consider | consider brother manager | teacher answer
#   69000000: whisper teacher | mysterious mother mysterious | remember brother
#   70000000: whisper beautiful | impossible do sister | consider mother
#   71000000: whisper discover | communication go happy | manager happy
#   72000000: answer mysterious | celebration soft mother | manager sister
#   73000000: answer consider | appreciate big brother | mysterious silly
#   74000000: answer teacher | incredible key answer | dangerous listen
#   75000000: answer daughter | important see whisper | impossible soft
#   76000000: brother dangerous | daughter whisper consider | communication faith
#   77000000: brother manager | teacher answer manager | communicate breath
#   78000000: brother remember | consider brother mysterious | communicate key
#   79000000: brother beautiful | mysterious mother dangerous | celebration be
#   80000000: brother daughter | impossible breath happy | understand soft
#   81000000: mother dangerous | communication go mother | appreciate faith
#   82000000: mother manager | celebration soft brother | incredible breath
#   83000000: mother remember | appreciate big answer | incredible key
#   84000000: mother beautiful | incredible key whisper | ambassador be
#   85000000: mother discover | important see pretty | important soft
#   86000000: happy mysterious | daughter whisper mysterious | happy teacher
#   87000000: happy consider | teacher answer dangerous | mother beautiful
#   88000000: happy teacher | consider answer discover | brother daughter
#   89000000: happy daughter | mysterious brother daughter | answer discover
#   90000000: happy discover | impossible breath brother | answer dangerous
#   91000000: dangerous silly | communication go answer | whisper mysterious
#   92000000: dangerous pretty | celebration soft whisper | pretty manager
#   93000000: dangerous answer | appreciate big pretty | listen consider
#   94000000: dangerous mother | incredible key listen | silly remember
#   95000000: mysterious sister | important see silly | sister teacher
#   96000000: mysterious listen | daughter whisper dangerous | do communicate
#   97000000: mysterious whisper | teacher whisper discover | breath communication
#   98000000: mysterious brother | consider answer daughter | big impossible
#   99000000: mysterious happy | mysterious brother beautiful | big important
#  100000000: manager sister | impossible breath answer | faith ambassador
#  101000000: manager listen | communication go whisper | strong incredible
#  102000000: manager whisper | celebration soft pretty | soft appreciate
#  103000000: manager brother | appreciate big listen | see understand
#  104000000: manager happy | incredible key silly | be celebration
#  105000000: consider silly | important see sister | go communicate
#  106000000: consider pretty | daughter pretty discover | key communication
#  107000000: consider answer | teacher whisper daughter | discover happy
#  108000000: consider mother | consider answer beautiful | discover sister
#  109000000: remember sister | mysterious brother teacher | daughter silly
#  110000000: remember silly | impossible breath whisper | beautiful listen
#  111000000: remember pretty | communication go pretty | teacher pretty
#  112000000: remember answer | celebration soft listen | remember whisper
#  113000000: remember mother | appreciate big silly | consider answer
#  114000000: teacher sister | incredible key sister | manager brother
#  115000000: teacher listen | important be happy | mysterious mother
#  116000000: teacher whisper | daughter pretty daughter | dangerous happy
#  117000000: teacher brother | teacher whisper beautiful | dangerous sister
#  118000000: teacher happy | consider answer teacher | impossible be
#  119000000: beautiful silly | mysterious brother remember | communication soft
#  120000000: beautiful listen | impossible breath pretty | communicate faith
#  121000000: beautiful whisper | communication go listen | celebration breath
#  122000000: beautiful brother | celebration soft silly | celebration key
#  123000000: beautiful happy | appreciate big sister | understand be
#  124000000: daughter silly | ambassador do happy | appreciate soft
#  125000000: daughter pretty | important be mother | incredible faith
#  126000000: daughter answer | daughter pretty beautiful | ambassador breath
#  127000000: daughter mother | teacher whisper teacher | ambassador key
#  128000000: discover sister | consider answer remember | important be
#  129000000: discover listen | mysterious brother manager | happy consider
#  130000000: discover pretty | impossible breath silly | mother remember
#  131000000: discover answer | communication go sister | brother teacher
#  132000000: discover mother | celebration see happy | answer beautiful
#  133000000: important key | appreciate faith mother | whisper daughter
#  134000000: important be | ambassador do brother | pretty discover
#  135000000: important soft | important be answer | pretty dangerous
#  136000000: important faith | daughter pretty remember | listen mysterious
#  137000000: important breath | teacher whisper consider | silly manager
#  138000000: ambassador key | consider answer manager | sister consider
#  139000000: ambassador be | mysterious brother mysterious | do understand
#  140000000: ambassador see | impossible breath sister | breath celebration
#  141000000: ambassador strong | communication key happy | big communicate
#  142000000: ambassador big | celebration see mother | faith communication
#  143000000: ambassador do | appreciate faith brother | strong impossible
#  144000000: incredible go | ambassador do answer | strong important
#  145000000: incredible see | important be whisper | soft ambassador
#  146000000: incredible strong | daughter pretty consider | see incredible
#  147000000: incredible big | teacher whisper manager | be appreciate
#  148000000: incredible do | consider answer mysterious | go understand
#  149000000: appreciate go | mysterious brother dangerous | key celebration
#  150000000: appreciate be | impossible big happy | discover brother
#  151000000: appreciate soft | communication key mother | daughter mother
#  152000000: appreciate faith | celebration see brother | beautiful happy
#  153000000: appreciate breath | appreciate faith answer | beautiful sister
#  154000000: understand key | ambassador do whisper | teacher silly
#  155000000: understand be | important be pretty | remember listen
#  156000000: understand soft | daughter pretty manager | consider pretty
#  157000000: understand faith | teacher whisper mysterious | manager whisper
#  158000000: understand breath | consider answer dangerous | mysterious answer
#  159000000: celebration key | mysterious answer discover | dangerous brother
#  160000000: celebration go | impossible big mother | impossible breath
#  161000000: celebration see | communication key brother | impossible key
#  162000000: celebration strong | celebration see answer | communication be
#  163000000: celebration big | appreciate faith whisper | communicate soft
#  164000000: celebration do | ambassador do pretty | celebration faith
#  165000000: communicate go | important be listen | understand breath
#  166000000: communicate see | daughter pretty mysterious | understand key
#  167000000: communicate strong | teacher whisper dangerous | appreciate be
#  168000000: communicate big | consider whisper discover | incredible soft
#  169000000: communicate do | mysterious answer daughter | ambassador faith
#  170000000: communication key | impossible big brother | important breath
#  171000000: communication be | communication key answer | important key
#  172000000: communication soft | celebration see pretty | happy mysterious
#  173000000: communication faith | appreciate faith listen | mother manager
#  174000000: communication breath | ambassador do silly | brother consider
#  175000000: impossible key | important be sister | answer remember
#  176000000: impossible be | daughter listen discover | whisper teacher
#  177000000: impossible soft | teacher pretty daughter | pretty beautiful
#  178000000: impossible faith | consider whisper beautiful | listen daughter
#  179000000: impossible breath | mysterious answer teacher | silly discover
#  180000000: impossible do | impossible big whisper | silly dangerous
#
# So far we have generated 180007596 sentences.
